# %%
pip install pandas==1.2.4
# Out:
# Collecting pandas==1.2.4
#   Downloading pandas-1.2.4.tar.gz (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 12.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.2.4) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.2.4) (2023.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from pandas==1.2.4) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.2.4) (1.16.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... done
#   Created wheel for pandas: filename=pandas-1.2.4-cp310-cp310-linux_x86_64.whl size=34330658 sha256=650661264e4743bfd45cfa34bfefe27190c3161b53bda8535596fd7f529ec3fc
#   Stored in directory: /root/.cache/pip/wheels/1b/10/28/2a37b26cf3e4dc59d82430e3812f8571518d2c1d81c288af98
# Successfully built pandas
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.15.1 requires pandas>=1.3.0, but you have pandas 1.2.4 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 1.2.4 which is incompatible.
# mizani 0.9.2 requires pandas>=1.3.5, but you have pandas 1.2.4 which is incompatible.
# plotnine 0.12.2 requires pandas>=1.5.0, but you have pandas 1.2.4 which is incompatible.
# xarray 2023.7.0 requires pandas>=1.4, but you have pandas 1.2.4 which is incompatible.
# yfinance 0.2.28 requires pandas>=1.3.0, but you have pandas 1.2.4 which is incompatible.
# Successfully installed pandas-1.2.4

# %%
pip install numpy==1.20.3
# Out:
# Collecting numpy==1.20.3
#   Downloading numpy-1.20.3.zip (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 15.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: numpy
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for numpy (pyproject.toml) ... error
#   ERROR: Failed building wheel for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 1.2.4
# 1.23.5

# %%
diagnosis_df=pd.read_csv("/content/drive/MyDrive/Stonny brook/diagnosis.csv")
patient_df = pd.read_csv("/content/drive/MyDrive/Stonny brook/patient.csv")
visit_df = pd.read_csv("/content/drive/MyDrive/Stonny brook/visit.csv")

# %%
diagnosis_df.head()
# Out:
#    person_id diagnosis_date  diagnosis_id diagnosis
# 0      10107     2016-04-06         54245      D1.2
# 1      10492     2017-05-18         54500      D1.2
# 2      11223     2021-06-24         58782      C1.1
# 3      10009     2017-05-24         59462      D1.2
# 4      10671     2016-06-21         62066      D1.2

# %%
patient_df.head()
# Out:
#    person_id date_of_birth gender
# 0      10000    1954-03-17      F
# 1      10001    1963-01-06      F
# 2      10002    1961-11-17      M
# 3      10003    1956-04-24      F
# 4      10004    1963-07-04      F

# %%
visit_df.head()
# Out:
#   unit_name  visit_id  visit_date test_name  test_value  person_id
# 0    Unit02     53816  2021-01-05     TestA   64.104983      11476
# 1    Unit01     54189  2016-07-18     TestC   68.506593      11134
# 2    Unit02     54406  2017-07-21     TestA   50.432863      10154
# 3    Unit02     56053  2019-09-10     TestA   74.358531      10261
# 4    Unit02     56740  2021-01-20     TestA   39.958341      11282

# %%
diagnosis_null_count=diagnosis_df.isnull().sum()
diagnosis_null_count
# Out:
# person_id         0
# diagnosis_date    0
# diagnosis_id      0
# diagnosis         0
# dtype: int64

# %%
visit_null_count=visit_df.isnull().sum()
visit_null_count
# Out:
# unit_name     0
# visit_id      0
# visit_date    0
# test_name     0
# test_value    0
# person_id     0
# dtype: int64

# %%
patient_null_count=patient_df.isnull().sum()
patient_null_count
# Out:
# person_id        0
# date_of_birth    0
# gender           0
# dtype: int64

# %%
visit_df.shape
# Out:
# (11346, 6)

# %%
diagnosis_df.shape
# Out:
# (3782, 4)

# %%
filtered_visit = visit_df[visit_df['unit_name'] == 'Unit01']
# filtered_df = np.where(diagnosis_df['diagnosis'] == 'D1.2'])

# %%
filtered_diagnosis = diagnosis_df[diagnosis_df['diagnosis'] == "D1.2" ]

# %%
filtered_visit.shape
#filtered_diagnosis.shape
# Out:
# (3315, 6)

# %%
filtered_visit
# Out:
#       unit_name  visit_id  visit_date test_name  test_value  person_id
# 1        Unit01     54189  2016-07-18     TestC   68.506593      11134
# 7        Unit01     59134  2017-06-27     TestC   27.982604      11767
# 9        Unit01     59944  2016-02-09     TestB   25.064054      11535
# 10       Unit01     61221  2021-03-29     TestC   97.890644      10179
# 13       Unit01     62350  2017-06-28     TestB   39.138280      11677
# ...         ...       ...         ...       ...         ...        ...
# 11327    Unit01   8036374  2017-07-19     TestB   49.876879      10328
# 11333    Unit01   8040724  2016-05-23     TestC   31.819107      10056
# 11337    Unit01   8042884  2017-03-20     TestB   93.558224      11416
# 11339    Unit01   8045469  2021-08-28     TestC   91.609087      11843
# 11345    Unit01   8051937  2016-06-13     TestB   70.770902      10742
#
# [3315 rows x 6 columns]

# %%
filtered_diagnosis.shape
# Out:
# (2782, 4)

# %%
filtered_diagnosis['diagnosis_date'] = pd.to_datetime(diagnosis_df['diagnosis_date'])
filtered_visit['visit_date'] = pd.to_datetime(filtered_visit['visit_date'])
# Out:
# <ipython-input-19-e2b89528e04d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_diagnosis['diagnosis_date'] = pd.to_datetime(diagnosis_df['diagnosis_date'])
# <ipython-input-19-e2b89528e04d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_visit['visit_date'] = pd.to_datetime(filtered_visit['visit_date'])

# %%
filtered_diagnosis.dtypes
# Out:
# person_id                  int64
# diagnosis_date    datetime64[ns]
# diagnosis_id               int64
# diagnosis                 object
# dtype: object

# %%
result_df = pd.DataFrame(columns = ['person_id','Diagnose_date','Visit_date'])
num_patients=0
for person_id in filtered_diagnosis['person_id'].unique():
  person_visit = filtered_visit[filtered_visit['person_id'] == person_id ]
  person_diagnosis = filtered_diagnosis[filtered_diagnosis['person_id'] == person_id]
  for _,diag_row in person_diagnosis.iterrows():
    for _,visit_row in person_visit.iterrows():
      if visit_row['visit_date'] > diag_row['diagnosis_date'] and visit_row['visit_date'] <= diag_row['diagnosis_date'] + pd.DateOffset(days=7):
        result_df = result_df.append( { 'person_id' : visit_row['person_id'],
                                         'Diagnose_date' : diag_row['diagnosis_date'],
                                          'Visit_date' : visit_row['visit_date']}, ignore_index=True
        )
        num_patients+=1

# %%
result_df.to_csv("result.csv")

# %%
print(num_patients)
# Out:
# 1920

# %%
merge_df = pd.merge(filtered_visit, filtered_diagnosis, on='person_id', how='inner')
merge_df = merge_df[(merge_df['visit_date'] > merge_df['diagnosis_date']) &
                    (merge_df['visit_date'] <= merge_df['diagnosis_date'] + pd.DateOffset(days=7))]

# %%
len(merge_df['person_id'])
# Out:
# 1920

# %%
result_df = result_df[result_df['person_id'].isin(merge_df['person_id'])]

# %%
result_df
# Out:
#      person_id Diagnose_date Visit_date
# 0        10107    2016-04-06 2016-04-11
# 1        10107    2017-05-08 2017-05-10
# 2        10492    2017-05-18 2017-05-21
# 3        10492    2017-07-14 2017-07-17
# 4        10492    2016-03-28 2016-04-01
# ...        ...           ...        ...
# 1915     10574    2021-08-04 2021-08-08
# 1916     10995    2021-05-07 2021-05-12
# 1917     10237    2021-01-14 2021-01-18
# 1918     11324    2021-01-28 2021-01-29
# 1919     10836    2021-05-04 2021-05-07
#
# [1920 rows x 3 columns]

# %%
pip install %git
# Out:
# ERROR: Invalid requirement: '%git'
